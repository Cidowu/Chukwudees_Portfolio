# %% [markdown]
# <a href="https://colab.research.google.com/github/Cidowu/Chukwudees_Portfolio/blob/main/act_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Report: act_report**
#
# ## **Contents**
#
#
# *   Introduction
# *   Insights
# *   Visualization
# *   Conclusion
#
#
#
# ### **Introduction**
#
# This report highlights the insights derived from the analysis of the data from the weRateDogs twitter archive. After cleaning, data from over 1600 tweets were analyzed in line with the predicted results from the image prediction algorithms. The aim of the analysis carried out is to understand the behaviour of the followers of the WeRateDogs twitter account to the different images of dog breeds posted, in terms of the retweet count, and favorite count. The analysis also tries to uncover what breeds are most popular among the other breeds.
#
# ![image.png](data:image/png;base64,...)
#
# ### **Insights**
#
# Five insights were derived during the analysis as listed below.
#
#
# *   Based on the predictor algorithms, how many breeds were successfully predicted
# *   Based on the predictor algorithms, what breed is most predicted
# *   Based on the predictor algorithms, what dog breed had the single highest retweet count, and favorite count
# *   What breed had the highest total retweet count
# *   What breed had the highest total favorite count
#
# **Based on the predictor algorithms, how many breeds were successfully predicted**
#
# There are 115 identified breeds from the analysed results. Some of which include; Welsh Springer Spaniel, Redbone, German Shepherd, Boxer, Cardigan
# Rhodesian Ridgeback, Miniature Pinscher, Rhodesian Ridgeback
# Bernese Mountain Dog, Chow, Miniature Poodle, Golden Retriever, Gordon Setter, Walker Hound, Pug, Bloodhound, Lhasa, English Setter, Italian Greyhound', Maltese Dog, etc.
#
#
# **Based on the predictor algorithms, what breed is most predicted**
#
# After Identifying the differnt breeds present in the dataset, it was important to understand the distribution and popularity of these breeds in the dataset. The Golden retriever was most predicted, with a population count of 162. This means that an image of a Golden retriever was posted on 162 occations, 55 times more than any other breed.
#
# **Based on the predictor algorithms, what dog breed had the single highest retweet count, and favorite count**
#
#
# Though the Golden retriever appears to be a very popular breed among the other breeds predicted by the predictor algorithms. In terms of likes and retweets, the Shih-tzu had the single highest retweet count and favorite count, 70,452 retweers, and 144,365 favorites respectively.
#
# ![image.png](data:image/png;base64,...)
#
#
# **What breed had the highest total retweet count**
#
# The records show that the Golden retriever has the highest cummulative total for retweet count, 336,433 retweets in total.
#
# **What breed had the highest total favorite count**
#
# The records also show that the Golden retriever has the highest cumulative total favorite count, 934,682 likes in total.
#
# ### **Visualization**
#
# Dog breed word cloud was created to visualize the popularity of each dog breed, in terms of how much each breed was predicted by the algorithm. The visuals displayed below show that the Golden retriever, Labrador retriever, Chihuahua, and Pembroke, are some of the most popular breeds frrom the WeRateDogs twitter archive.
#
# ![image.png](data:image/png;base64,...)
#
# ### **Conclusion**
#
# In summary, the insights gathered from the analysis showed that the Golden retriever is a popular breed among a lot of the followers of the WeRateDogs twitter account. Though image quality and photo angles play a big role in the amount of likes and retweets an dog image may get, the Golden retrieve, and the labrador retriever appear to be very popular among a lot of dog lovers of the WeRateDogs twitter page.
